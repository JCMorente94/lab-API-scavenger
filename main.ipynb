# %% [markdown]
# # Challenge 1

# %%
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize
import base64

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'


response = requests.get(url)
results = response.json()
results
# Out:
# [{'id': 220066216,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=',
#   'name': 'mad-oct-2018',
#   'full_name': 'ToniPons97/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'ToniPons97',
#    'id': 45130294,
#    'node_id': 'MDQ6VXNlcjQ1MTMwMjk0',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/45130294?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ToniPons97',
#    'html_url': 'https://github.com/ToniPons97',
#    'followers_url': 'https://api.github.com/users/ToniPons97/followers',
#    'following_url': 'https://api.github.com/users/ToniPons97/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ToniPons97/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ToniPons97/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ToniPons97/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ToniPons97/orgs',
# ...

# %%
x.keys()
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
x = json_normalize(results)
x
# Out:
#            id                           node_id             name  \
# 0   220066216  MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=     mad-oct-2018
# 1   204100911  MDEwOlJlcG9zaXRvcnkyMDQxMDA5MTE=     mad-oct-2018
# 2   200138127  MDEwOlJlcG9zaXRvcnkyMDAxMzgxMjc=     mad-oct-2018
# 3   198273438  MDEwOlJlcG9zaXRvcnkxOTgyNzM0Mzg=     mad-oct-2018
# 4   167001044  MDEwOlJlcG9zaXRvcnkxNjcwMDEwNDQ=      datamad0119
# 5   162498469  MDEwOlJlcG9zaXRvcnkxNjI0OTg0Njk=  madrid-oct-2018
# 6   154625001  MDEwOlJlcG9zaXRvcnkxNTQ2MjUwMDE=  madrid-oct-2018
# 7   154291113  MDEwOlJlcG9zaXRvcnkxNTQyOTExMTM=  madrid-oct-2018
# 8   154191482  MDEwOlJlcG9zaXRvcnkxNTQxOTE0ODI=  madrid-oct-2018
# 9   154163166  MDEwOlJlcG9zaXRvcnkxNTQxNjMxNjY=  madrid-oct-2018
# 10  154105473  MDEwOlJlcG9zaXRvcnkxNTQxMDU0NzM=  madrid-oct-2018
# 11  153788059  MDEwOlJlcG9zaXRvcnkxNTM3ODgwNTk=  madrid-oct-2018
# 12  153787890  MDEwOlJlcG9zaXRvcnkxNTM3ODc4OTA=  madrid-oct-2018
# ...

# %%
lst_languages = []
for i in x.language:
    if i not in lst_languages and i != None:
        lst_languages.append(i)
lst_languages
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
x.commits_url.count()
# Out:
# 16

# %%
url1 = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits'

# %%
response = requests.get(url1)
results = response.json()
results
# Out:
# [{'sha': '1638e5506e6947b77bfe78761d345476ae80d017',
#   'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OjE2MzhlNTUwNmU2OTQ3Yjc3YmZlNzg3NjFkMzQ1NDc2YWU4MGQwMTc=',
#   'commit': {'author': {'name': 'Marc Pomar',
#     'email': 'marc@faable.com',
#     'date': '2019-08-19T11:11:36Z'},
#    'committer': {'name': 'Marc Pomar',
#     'email': 'marc@faable.com',
#     'date': '2019-08-19T11:11:36Z'},
#    'message': 'Cambiar los autores',
#    'tree': {'sha': '51812285dc70ac37103735ee7ed672befc582b5f',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/51812285dc70ac37103735ee7ed672befc582b5f'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/1638e5506e6947b77bfe78761d345476ae80d017',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
y = json_normalize(results)
y.keys()
# Out:
# Index(['sha', 'node_id', 'url', 'html_url', 'comments_url', 'parents',
#        'commit.author.name', 'commit.author.email', 'commit.author.date',
#        'commit.committer.name', 'commit.committer.email',
#        'commit.committer.date', 'commit.message', 'commit.tree.sha',
#        'commit.tree.url', 'commit.url', 'commit.comment_count',
#        'commit.verification.verified', 'commit.verification.reason',
#        'commit.verification.signature', 'commit.verification.payload',
#        'author.login', 'author.id', 'author.node_id', 'author.avatar_url',
#        'author.gravatar_id', 'author.url', 'author.html_url',
#        'author.followers_url', 'author.following_url', 'author.gists_url',
#        'author.starred_url', 'author.subscriptions_url',
#        'author.organizations_url', 'author.repos_url', 'author.events_url',
#        'author.received_events_url', 'author.type', 'author.site_admin',
#        'committer.login', 'committer.id', 'committer.node_id',
# ...

# %%
y['commit.author.date'].count()
# Out:
# 30

# %%
url2 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351'


response = requests.get(url2)
results = response.json()
results
# Out:
# {'message': "API rate limit exceeded for 83.56.176.29. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)",
#  'documentation_url': 'https://developer.github.com/v3/#rate-limiting'}

# %%
"""z = pd.DataFrame(y.content)
import base64
base64.b64decode(z.content[0])"""
# Out:
# 'z = pd.DataFrame(y.content)\nimport base64\nbase64.b64decode(z.content[0])'

# %%
y = json_normalize(results)
lst=[]
for i in y['name']:
    if len(i) == 5:
        lst.append(i)
lst
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-177-9776374a86e7> in <module>
#       1 y = json_normalize(results)
#       2 lst=[]
# ...

# %%
lst_sca = []
for i in lst:
    url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/' + i
    
    response = requests.get(url)
    results = response.json()
    if len(results[0]['name']) == 18:
        lst_sca.append(results[0]['name'])
lst_sca
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-174-88c56aa5963f> in <module>
#       5     response = requests.get(url)
#       6     results = response.json()
# ----> 7     if len(results[0]['name']) == 18:
#       8         lst_sca.append(results[0]['name'])
#       9 lst_sca
#
# KeyError: 0

# %%
# Out:
#            id                           node_id                        name  \
# 0   169605092  MDEwOlJlcG9zaXRvcnkxNjk2MDUwOTI=                bcn-feb-2019
# 1   170384482  MDEwOlJlcG9zaXRvcnkxNzAzODQ0ODI=        bcn-feb-2019-prework
# 2   231368458  MDEwOlJlcG9zaXRvcnkyMzEzNjg0NTg=              data-ber-01-20
# 3   213957020  MDEwOlJlcG9zaXRvcnkyMTM5NTcwMjA=              data-ber-10-19
# 4   188433440  MDEwOlJlcG9zaXRvcnkxODg0MzM0NDA=              databcn0519-pt
# 5   188459756  MDEwOlJlcG9zaXRvcnkxODg0NTk3NTY=                 databer0619
# 6   196546532  MDEwOlJlcG9zaXRvcnkxOTY1NDY1MzI=       databer0619-solutions
# 7   198647222  MDEwOlJlcG9zaXRvcnkxOTg2NDcyMjI=                 datalis0819
# 8   167007163  MDEwOlJlcG9zaXRvcnkxNjcwMDcxNjM=                 datamad0119
# 9   233579456  MDEwOlJlcG9zaXRvcnkyMzM1Nzk0NTY=                 datamad0120
# 10  180311907  MDEwOlJlcG9zaXRvcnkxODAzMTE5MDc=                 datamad0419
# ...
